# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
uber_data=pd.read_csv("//content//uber.csv")
uber_data
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 0         24238194    2015-05-07 19:52:06.0000003          7.5
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 199995    42598914   2012-10-28 10:49:00.00000053          3.0
# 199996    16382965    2014-03-14 01:09:00.0000008          7.5
# 199997    27804658   2009-06-29 00:42:00.00000078         30.9
# 199998    20259894    2015-05-20 14:56:25.0000004         14.5
# 199999    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1       2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2       2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3       2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4       2014-08-28 17:47:00 UTC        -73.925023        40.744085
# ...                         ...               ...              ...
# 199995  2012-10-28 10:49:00 UTC        -73.987042        40.739367
# 199996  2014-03-14 01:09:00 UTC        -73.984722        40.736837
# 199997  2009-06-29 00:42:00 UTC        -73.986017        40.756487
# 199998  2015-05-20 14:56:25 UTC        -73.997124        40.725452
# 199999  2010-05-15 04:08:00 UTC        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# 0              -73.999512         40.723217                1
# 1              -73.994710         40.750325                1
# 2              -73.962565         40.772647                1
# 3              -73.965316         40.803349                3
# 4              -73.973082         40.761247                5
# ...                   ...               ...              ...
# 199995         -73.986525         40.740297                1
# 199996         -74.006672         40.739620                1
# 199997         -73.858957         40.692588                2
# 199998         -73.983215         40.695415                1
# 199999         -73.985508         40.768793                1
#
# [200000 rows x 9 columns]

# %%
uber_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
uber_data.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
uber_data.describe()
# Out:
#          Unnamed: 0    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967154        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# 25%           -73.991407         40.733823         1.000000
# 50%           -73.980093         40.753042         1.000000
# 75%           -73.963658         40.768001         2.000000
# max          1153.572603        872.697628       208.000000

# %%
uber_data.describe(include='all')
# Out:
#           Unnamed: 0                          key    fare_amount  \
# count   2.000000e+05                       200000  200000.000000
# unique           NaN                       200000            NaN
# top              NaN  2015-05-07 19:52:06.0000003            NaN
# freq             NaN                            1            NaN
# mean    2.771250e+07                          NaN      11.359955
# std     1.601382e+07                          NaN       9.901776
# min     1.000000e+00                          NaN     -52.000000
# 25%     1.382535e+07                          NaN       6.000000
# 50%     2.774550e+07                          NaN       8.500000
# 75%     4.155530e+07                          NaN      12.500000
# max     5.542357e+07                          NaN     499.000000
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# count                    200000     200000.000000    200000.000000
# unique                   196629               NaN              NaN
# top     2014-04-13 18:19:00 UTC               NaN              NaN
# freq                          4               NaN              NaN
# mean                        NaN        -72.527638        39.935885
# std                         NaN         11.437787         7.720539
# min                         NaN      -1340.648410       -74.015515
# 25%                         NaN        -73.992065        40.734796
# 50%                         NaN        -73.981823        40.752592
# 75%                         NaN        -73.967154        40.767158
# max                         NaN         57.418457      1644.421482
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# count       199999.000000     199999.000000    200000.000000
# unique                NaN               NaN              NaN
# top                   NaN               NaN              NaN
# freq                  NaN               NaN              NaN
# mean           -72.525292         39.923890         1.684535
# std             13.117408          6.794829         1.385997
# min          -3356.666300       -881.985513         0.000000
# 25%            -73.991407         40.733823         1.000000
# 50%            -73.980093         40.753042         1.000000
# 75%            -73.963658         40.768001         2.000000
# max           1153.572603        872.697628       208.000000

# %%
data_overview = {
    "Shape of the dataset ":uber_data.shape,
    "Columns name ":uber_data.columns.tolist(),
    "Data Types ":uber_data.dtypes.to_dict(),
    "First Few words ":uber_data.head(),
}

# %%
data_overview
# Out:
# {'Shape of the dataset ': (200000, 9),
#  'Columns name ': ['Unnamed: 0',
#   'key',
#   'fare_amount',
#   'pickup_datetime',
#   'pickup_longitude',
#   'pickup_latitude',
#   'dropoff_longitude',
#   'dropoff_latitude',
#   'passenger_count'],
#  'Data Types ': {'Unnamed: 0': dtype('int64'),
#   'key': dtype('O'),
#   'fare_amount': dtype('float64'),
#   'pickup_datetime': dtype('O'),
#   'pickup_longitude': dtype('float64'),
#   'pickup_latitude': dtype('float64'),
#   'dropoff_longitude': dtype('float64'),
#   'dropoff_latitude': dtype('float64'),
#   'passenger_count': dtype('int64')},
#  'First Few words ':    Unnamed: 0                            key  fare_amount  \
#  0    24238194    2015-05-07 19:52:06.0000003          7.5
#  1    27835199    2009-07-17 20:04:56.0000002          7.7
#  2    44984355   2009-08-24 21:45:00.00000061         12.9
#  3    25894730    2009-06-26 08:22:21.0000001          5.3
#  4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#             pickup_datetime  pickup_longitude  pickup_latitude  \
#  0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
#  1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
#  2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
#  3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
#  4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#     dropoff_longitude  dropoff_latitude  passenger_count
#  0         -73.999512         40.723217                1
#  1         -73.994710         40.750325                1
#  2         -73.962565         40.772647                1
#  3         -73.965316         40.803349                3
#  4         -73.973082         40.761247                5  }

# %%
# lets check missing values

mis_val = uber_data.isnull().sum()

# Summary statistics for numerical columns

summary_statistics = uber_data.describe()

# Displaying the missing values and summary statistics

mis_val,summary_statistics
# Out:
# (Unnamed: 0           0
#  key                  0
#  fare_amount          0
#  pickup_datetime      0
#  pickup_longitude     0
#  pickup_latitude      0
#  dropoff_longitude    1
#  dropoff_latitude     1
#  passenger_count      0
#  dtype: int64,
#           Unnamed: 0    fare_amount  pickup_longitude  pickup_latitude  \
#  count  2.000000e+05  200000.000000     200000.000000    200000.000000
#  mean   2.771250e+07      11.359955        -72.527638        39.935885
#  std    1.601382e+07       9.901776         11.437787         7.720539
#  min    1.000000e+00     -52.000000      -1340.648410       -74.015515
#  25%    1.382535e+07       6.000000        -73.992065        40.734796
#  50%    2.774550e+07       8.500000        -73.981823        40.752592
#  75%    4.155530e+07      12.500000        -73.967154        40.767158
#  max    5.542357e+07     499.000000         57.418457      1644.421482
#
#         dropoff_longitude  dropoff_latitude  passenger_count
#  count      199999.000000     199999.000000    200000.000000
#  mean          -72.525292         39.923890         1.684535
#  std            13.117408          6.794829         1.385997
#  min         -3356.666300       -881.985513         0.000000
#  25%           -73.991407         40.733823         1.000000
#  50%           -73.980093         40.753042         1.000000
#  75%           -73.963658         40.768001         2.000000
#  max          1153.572603        872.697628       208.000000  )

# %%
# Dropping rows with missing values

uber_data_cleaned = uber_data.dropna()

# Confirming no missing values remain

print("Missing values after cleaning:",uber_data_cleaned.isnull().sum())
# Out:
# Missing values after cleaning: Unnamed: 0           0
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# dtype: int64

# %%
# Filtering fare amount between reasonable limits

uber_data_cleaned = uber_data_cleaned[(uber_data_cleaned['fare_amount']>=0) &
                                    (uber_data_cleaned['fare_amount']<=200) ]

# %%
uber_data_cleaned
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 0         24238194    2015-05-07 19:52:06.0000003          7.5
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 199995    42598914   2012-10-28 10:49:00.00000053          3.0
# 199996    16382965    2014-03-14 01:09:00.0000008          7.5
# 199997    27804658   2009-06-29 00:42:00.00000078         30.9
# 199998    20259894    2015-05-20 14:56:25.0000004         14.5
# 199999    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1       2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2       2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3       2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4       2014-08-28 17:47:00 UTC        -73.925023        40.744085
# ...                         ...               ...              ...
# 199995  2012-10-28 10:49:00 UTC        -73.987042        40.739367
# 199996  2014-03-14 01:09:00 UTC        -73.984722        40.736837
# 199997  2009-06-29 00:42:00 UTC        -73.986017        40.756487
# 199998  2015-05-20 14:56:25 UTC        -73.997124        40.725452
# 199999  2010-05-15 04:08:00 UTC        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# 0              -73.999512         40.723217                1
# 1              -73.994710         40.750325                1
# 2              -73.962565         40.772647                1
# 3              -73.965316         40.803349                3
# 4              -73.973082         40.761247                5
# ...                   ...               ...              ...
# 199995         -73.986525         40.740297                1
# 199996         -74.006672         40.739620                1
# 199997         -73.858957         40.692588                2
# 199998         -73.983215         40.695415                1
# 199999         -73.985508         40.768793                1
#
# [199975 rows x 9 columns]

# %%
# validating latitude and longitude ranges

valid_lst = (uber_data_cleaned['pickup_latitude'].between(-90,90) &\
             uber_data_cleaned['dropoff_latitude'].between(-90,90))
valid_lon = (uber_data_cleaned['pickup_longitude'].between(-180,180) &\
             uber_data_cleaned['dropoff_longitude'].between(-180,180))

# filtering valid latitude and longitude
uber_data_cleaned = uber_data_cleaned[valid_lst & valid_lon]

# %%
valid_lst
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 199995    True
# 199996    True
# 199997    True
# 199998    True
# 199999    True
# Length: 199975, dtype: bool

# %%
valid_lon
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 199995    True
# 199996    True
# 199997    True
# 199998    True
# 199999    True
# Length: 199975, dtype: bool

# %%
uber_data_cleaned
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 0         24238194    2015-05-07 19:52:06.0000003          7.5
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 199995    42598914   2012-10-28 10:49:00.00000053          3.0
# 199996    16382965    2014-03-14 01:09:00.0000008          7.5
# 199997    27804658   2009-06-29 00:42:00.00000078         30.9
# 199998    20259894    2015-05-20 14:56:25.0000004         14.5
# 199999    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1       2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2       2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3       2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4       2014-08-28 17:47:00 UTC        -73.925023        40.744085
# ...                         ...               ...              ...
# 199995  2012-10-28 10:49:00 UTC        -73.987042        40.739367
# 199996  2014-03-14 01:09:00 UTC        -73.984722        40.736837
# 199997  2009-06-29 00:42:00 UTC        -73.986017        40.756487
# 199998  2015-05-20 14:56:25 UTC        -73.997124        40.725452
# 199999  2010-05-15 04:08:00 UTC        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# 0              -73.999512         40.723217                1
# 1              -73.994710         40.750325                1
# 2              -73.962565         40.772647                1
# 3              -73.965316         40.803349                3
# 4              -73.973082         40.761247                5
# ...                   ...               ...              ...
# 199995         -73.986525         40.740297                1
# 199996         -74.006672         40.739620                1
# 199997         -73.858957         40.692588                2
# 199998         -73.983215         40.695415                1
# 199999         -73.985508         40.768793                1
#
# [199963 rows x 9 columns]

# %%
# restricting passenger count to a reasonable range (1 to 6 for typical cabs)
uber_data_cleaned = uber_data_cleaned[(uber_data_cleaned['passenger_count']>=0) &
                                    (uber_data_cleaned['passenger_count']<=6) ]

# %%
uber_data_cleaned
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 0         24238194    2015-05-07 19:52:06.0000003          7.5
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 199995    42598914   2012-10-28 10:49:00.00000053          3.0
# 199996    16382965    2014-03-14 01:09:00.0000008          7.5
# 199997    27804658   2009-06-29 00:42:00.00000078         30.9
# 199998    20259894    2015-05-20 14:56:25.0000004         14.5
# 199999    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1       2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2       2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3       2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4       2014-08-28 17:47:00 UTC        -73.925023        40.744085
# ...                         ...               ...              ...
# 199995  2012-10-28 10:49:00 UTC        -73.987042        40.739367
# 199996  2014-03-14 01:09:00 UTC        -73.984722        40.736837
# 199997  2009-06-29 00:42:00 UTC        -73.986017        40.756487
# 199998  2015-05-20 14:56:25 UTC        -73.997124        40.725452
# 199999  2010-05-15 04:08:00 UTC        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# 0              -73.999512         40.723217                1
# 1              -73.994710         40.750325                1
# 2              -73.962565         40.772647                1
# 3              -73.965316         40.803349                3
# 4              -73.973082         40.761247                5
# ...                   ...               ...              ...
# 199995         -73.986525         40.740297                1
# 199996         -74.006672         40.739620                1
# 199997         -73.858957         40.692588                2
# 199998         -73.983215         40.695415                1
# 199999         -73.985508         40.768793                1
#
# [199962 rows x 9 columns]

# %%
# distance calculation
from geopy.distance import geodesic
# function to calculate geosedic distance
def cal_dis(row):
  pick = (row['pickup_latitude'],row['pickup_longitude'])
  drop = (row['dropoff_latitude'],row['dropoff_longitude'])
  return geodesic(pick,drop).km

# applying distance calculation
uber_data_cleaned['trip_distance_km'] = uber_data_cleaned.apply(cal_dis,axis=1)
# Out:
# <ipython-input-19-7c6dc29d03bc>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data_cleaned['trip_distance_km'] = uber_data_cleaned.apply(cal_dis,axis=1)

# %%
uber_data_cleaned
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 0         24238194    2015-05-07 19:52:06.0000003          7.5
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 199995    42598914   2012-10-28 10:49:00.00000053          3.0
# 199996    16382965    2014-03-14 01:09:00.0000008          7.5
# 199997    27804658   2009-06-29 00:42:00.00000078         30.9
# 199998    20259894    2015-05-20 14:56:25.0000004         14.5
# 199999    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1       2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2       2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3       2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4       2014-08-28 17:47:00 UTC        -73.925023        40.744085
# ...                         ...               ...              ...
# 199995  2012-10-28 10:49:00 UTC        -73.987042        40.739367
# 199996  2014-03-14 01:09:00 UTC        -73.984722        40.736837
# 199997  2009-06-29 00:42:00 UTC        -73.986017        40.756487
# 199998  2015-05-20 14:56:25 UTC        -73.997124        40.725452
# 199999  2010-05-15 04:08:00 UTC        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count  trip_distance_km
# 0              -73.999512         40.723217                1          1.681111
# 1              -73.994710         40.750325                1          2.454363
# 2              -73.962565         40.772647                1          5.039603
# 3              -73.965316         40.803349                3          1.661442
# 4              -73.973082         40.761247                5          4.483730
# ...                   ...               ...              ...               ...
# 199995         -73.986525         40.740297                1          0.112128
# 199996         -74.006672         40.739620                1          1.879635
# 199997         -73.858957         40.692588                2         12.867916
# 199998         -73.983215         40.695415                1          3.536552
# 199999         -73.985508         40.768793                1          5.410678
#
# [199962 rows x 10 columns]

# %%
# passenger count

plt.figure(figsize=(8,6))
sns.countplot(x='passenger_count',data=uber_data_cleaned)
plt.title('Count of Passengers')
plt.xlabel('passenger count')
plt.ylabel('Count')
plt.show()

# %%
uber_data_cleaned['pickup_datetime'] = pd.to_datetime(uber_data_cleaned['pickup_datetime'])
uber_data_cleaned['pickup_hour'] = uber_data_cleaned['pickup_datetime'].dt.hour
uber_data_cleaned['pickup_day'] = uber_data_cleaned['pickup_datetime'].dt.day
uber_data_cleaned['pickup_month'] = uber_data_cleaned['pickup_datetime'].dt.month

uber_data_cleaned['pickup_year'] = uber_data_cleaned['pickup_datetime'].dt.year
# Out:
# <ipython-input-22-86cbeab7bf15>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data_cleaned['pickup_datetime'] = pd.to_datetime(uber_data_cleaned['pickup_datetime'])
# <ipython-input-22-86cbeab7bf15>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data_cleaned['pickup_hour'] = uber_data_cleaned['pickup_datetime'].dt.hour
# <ipython-input-22-86cbeab7bf15>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data_cleaned['pickup_day'] = uber_data_cleaned['pickup_datetime'].dt.day
# <ipython-input-22-86cbeab7bf15>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data_cleaned['pickup_month'] = uber_data_cleaned['pickup_datetime'].dt.month
# <ipython-input-22-86cbeab7bf15>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data_cleaned['pickup_year'] = uber_data_cleaned['pickup_datetime'].dt.year

# %%
from sklearn.model_selection import train_test_split

# defining features and target

features = uber_data_cleaned[['trip_distance_km','pickup_hour','pickup_day','pickup_month','pickup_year','passenger_count']]

target = uber_data_cleaned['fare_amount']

# splitting data into training and esting sets

x_train , x_test , y_train , y_test = train_test_split(features , target , test_size = 0.2, random_state = 42)

# %%
# training and testing

from sklearn.linear_model import LinearRegression

# initializing linear regression model

model = LinearRegression()

# training the model

model.fit(x_train , y_train)

# predicting on the test set

y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error , r2_score

# calculating evaluation metrics

mae = mean_absolute_error(y_test ,y_pred)

mse = mean_squared_error(y_test ,y_pred)

rmse = mse ** 0.5

#displaying metrics

print(f"MAE: {mae}, MSE:{mse}, RMSE: {rmse}")

r2 = r2_score(y_test , y_pred)

print(f"R2 Score: {r2}")
# Out:
# MAE: 5.938743819571382, MSE:93.89240182262336, RMSE: 9.689809173694979
# R2 Score: 0.01708781628581868

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error , mean_absolute_error , r2_score

gb = GradientBoostingRegressor()
gb.fit(x_train , y_train)
y_pred = model.predict(x_test)

mae = mean_absolute_error(y_test ,y_pred)
mse = mean_squared_error(y_test ,y_pred)
rmse = mse ** 0.5

print(f"MAE: {mae}, MSE:{mse}, RMSE: {rmse}")
r2 = r2_score(y_test , y_pred)
print(f"R2 Score: {r2}")
# Out:
# MAE: 5.938743819571382, MSE:93.89240182262336, RMSE: 9.689809173694979
# R2 Score: 0.01708781628581868

# %%
from xgboost import XGBRegressor
#from sklearn.metrics import mean_squared_error , mean_absolute_error , r2_score

xgb = XGBRegressor()
xgb.fit(x_train , y_train)
y_pred = model.predict(x_test)

mae = mean_absolute_error(y_test ,y_pred)
mse = mean_squared_error(y_test ,y_pred)
rmse = mse ** 0.5

print(f"MAE: {mae}, MSE:{mse}, RMSE: {rmse}")
r2 = r2_score(y_test , y_pred)
print(f"R2 Score: {r2}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1a88c01f126d> in <cell line: 5>()
#       3
#       4 xgb = XGBRegressor()
# ----> 5 xgb.fit(x_train , y_train)
#       6 y_pred = model.predict(x_test)
#       7
#
# NameError: name 'x_train' is not defined
